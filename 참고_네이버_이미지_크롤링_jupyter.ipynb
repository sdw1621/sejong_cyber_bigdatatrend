# %% [markdown]
# <a href="https://colab.research.google.com/github/sdw1621/sejong_cyber_bigdatatrend/blob/main/%EC%B0%B8%EA%B3%A0_%EB%84%A4%EC%9D%B4%EB%B2%84_%EC%9D%B4%EB%AF%B8%EC%A7%80_%ED%81%AC%EB%A1%A4%EB%A7%81_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://youtu.be/HJN28B7OSzw

# 셀레늄 패키지 가져오기, 크롬 브라우저 컨트롤 하는 webdriver
from selenium import webdriver

# click()을 대신, key로 입력하는 코드(키로 동작 가능하게 만듦)
from selenium.webdriver.common.keys import Keys

# 시스템 동작을 잠시 멈춰줌 (아주 중요 : 마치 사람이 클릭하는 속도를 맞추기 위함)
import time

# 프로그래스 바(진행바를 만들어 줌)
from tqdm import tqdm

# 검색어
keyword = "방탄소년단"

# 웹 접속 - 네이버 이미지 접속
# 지금 시작!
print("접속중")

# webdriver 크롬 브라우저를 컨트롤, Chrome함수(위치하는 경로)
driver = webdriver.Chrome('c:/chromedriver.exe')

# implicitly_wait : 명시적으로 기다려 / implicitly_wait(30) : 최대 30초 기다림, 그 전에 완료되면 진행
# time.sleep(1) : 무조건 1초 동안 기다려
# 시스템, 데이터 로딩을 봐서 개발자가 셋팅
driver.implicitly_wait(30)

# url : uniform resource locator : 유일무의한 인터넷 자원의 위치
url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query={}'.format(keyword)
driver.get(url)
# Out:
# 접속중

# %%
# 통합검색에서 방탄소년단을 검색하게끔 해보세요!

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from tqdm import tqdm

keyword = "방탄소년단"
print("접속중")

driver = webdriver.Chrome('c:/chromedriver.exe')
driver.implicitly_wait(30)

# url : uniform resource locator : 유일무의한 인터넷 자원의 위치
url = 'https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query={}'.format(keyword)
driver.get(url)
# Out:
# 접속중
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-625f6d994dc0> in <module>
#      14 # url : uniform resource locator : 유일무의한 인터넷 자원의 위치
#      15 url = 'https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query={}'.format(keyword)
# ---> 16 driver.get(url)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

keyword = "방탄소년단"

# 웹 접속 - 네이버 이미지 접속
print("접속중")
driver = webdriver.Chrome('c:/chromedriver.exe')
driver.implicitly_wait(30)

url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query={}'.format(keyword)
driver.get(url)

#이미지 링크 수집
imgs = driver.find_elements_by_css_selector('img._img')

# print(imgs)

result = []
for img in imgs:
    if 'http' in img.get_attribute('src'):
        result.append(img.get_attribute('src'))
# print(result)

driver.close()
print("수집완료")
# Out:
# 접속중
# 수집완료

# %%
print(result)
# Out:
# ['https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAxOTExMjBfMTI3%2FMDAxNTc0MjA1NzEyNjk2.NH-4r8xAGSIwfjJbYhKrYY-bSoHcey3AmOsGFkcepmog.1kHGj8PrltRVNZK2ZF2Eq1krv1rFqkGuffhea55BLRYg.JPEG.nailus5%2F1574205714210.jpg&type=b400', 'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMDA2MDJfMjQ5%2FMDAxNTkxMDI3NDg0ODI3.Uyt4ouuUipxs7xDwMusbdxvKNPJB2i8TSSuZjL6dw_cg.0hLPnr_ShY9TlrujHuUbDyxxRpte5MlSnUTjvKRAjnIg.JPEG.megomi%2F1591027484142.jpg&type=b400', 'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMDA1MDVfMTAg%2FMDAxNTg4NjQzMTQwMjEy.K9xXit-OJy25aUjWaz4RmQNfR6WgMjpyq0xRiV11QU0g.Iaop2yytwiHvLo2Sf6LZdPTjx59nyIo1t_2oq3EKduAg.JPEG.okmijnuhb489%2F1588643138187.jpg&type=b400', 'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMDA2MjRfMTAx%2FMDAxNTkyOTcxNTIxODk0.HaK_OaRhopWv9q_czd8tZjwWS61PP62xJD8pz7C8KYcg.AazkGhsIgBEhL3kVJp9D1ZnarxLcWq86PeMA1J6glYkg.JPEG.me_sun1223%2F1592971521295.jpg&ty
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

keyword = "방탄소년단"

# 웹 접속 - 네이버 이미지 접속
print("접속중")
driver = webdriver.Chrome('c:/chromedriver.exe')
driver.implicitly_wait(30)

url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query={}'.format(keyword)
driver.get(url)

#이미지 링크 수집
imgs = driver.find_elements_by_css_selector('img._img')
result = []
for img in imgs:
    if 'http' in img.get_attribute('src'):
        result.append(img.get_attribute('src'))
# print(result)

driver.close()
print("수집완료")

#폴더생성   
print("폴더생성")

# os = operate system : win 10
import os

# os.path.isdir => os : win 10, path : 경로, is : 있냐?, dir : 폴더 
# 윈도우 10아 내가 설정한 경로에 폴더가 존재하니?
# not : 반대
# 윈도우 10아 내가 설정한 경로에 폴더가 존재하지 않니?
# if : 만약에
# 만약에 윈도우 10아 내가 설정한 경로(C:/Users/sdw19/0_naver_image_crawling/방탄소년단)에 폴더가 존재하지 않으면
if not os.path.isdir('C:/Users/sdw19/0_naver_image_crawling/{}'.format(keyword)):
    # os : win10아, mk : make, dir : 폴더 : 윈도우 10아 내가 설정한 경로(C:/Users/sdw19/0_naver_image_crawling/방탄소년단)에 폴더 만들어 줘
    os.mkdir('C:/Users/sdw19/0_naver_image_crawling/{}'.format(keyword))
# Out:
# 접속중
# 수집완료
# 폴더생성

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

keyword = "방탄소년단"

# 웹 접속 - 네이버 이미지 접속
print("접속중")
driver = webdriver.Chrome('c:/chromedriver.exe')
driver.implicitly_wait(30)

url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query={}'.format(keyword)
driver.get(url)

#이미지 링크 수집
imgs = driver.find_elements_by_css_selector('img._img')
result = []
for img in imgs:
    if 'http' in img.get_attribute('src'):
        result.append(img.get_attribute('src'))
# print(result)

driver.close()
print("수집완료")

#폴더생성
print("폴더생성")
import os
if not os.path.isdir('C:/Users/sdw19/0_naver_image_crawling/{}'.format(keyword)):
    os.mkdir('C:/Users/sdw19/0_naver_image_crawling/{}'.format(keyword))

#다운로드
print("다운로드")
from urllib.request import urlretrieve
for index , link in tqdm(enumerate(result)):
    start = link.rfind('.')
    end = link.rfind('&')
    # print(link[start:end])
    filetype = link[start:end] #.png

    urlretrieve(link , 'C:/Users/sdw19/0_naver_image_crawling/{}/{}{}{}'.format(keyword,keyword,index,filetype))

print("다운로드 완료")
# Out:
# 접속중
# 2it [00:00, 13.03it/s]
# 수집완료
# 폴더생성
# 다운로드
# 23it [00:01, 13.12it/s]
# 다운로드 완료

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

keyword = "방탄소년단"

# 웹 접속 - 네이버 이미지 접속
print("접속중")
driver = webdriver.Chrome('c:/chromedriver.exe')
driver.implicitly_wait(30)

url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query={}'.format(keyword)
driver.get(url)

#페이지 스크롤 다운
body = driver.find_element_by_css_selector('body')
for i in range(10):
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)

#이미지 링크 수집
imgs = driver.find_elements_by_css_selector('img._img')
result = []
for img in imgs:
    if 'http' in img.get_attribute('src'):
        result.append(img.get_attribute('src'))
# print(result)

driver.close()
print("수집완료")

#폴더생성
print("폴더생성")
import os
if not os.path.isdir('C:/Users/sdw19/0_naver_image_crawling/{}'.format(keyword)):
    os.mkdir('C:/Users/sdw19/0_naver_image_crawling/{}'.format(keyword))

#다운로드
print("다운로드")
from urllib.request import urlretrieve
for index , link in tqdm(enumerate(result)):
    start = link.rfind('.')
    end = link.rfind('&')
    # print(link[start:end])
    filetype = link[start:end] #.png

    urlretrieve(link , 'C:/Users/sdw19/0_naver_image_crawling/{}/{}{}{}'.format(keyword,keyword,index,filetype))

print("다운로드 완료")
# Out:
# 접속중
# 0it [00:00, ?it/s]
# 수집완료
# 폴더생성
# 다운로드
# 250it [00:22, 11.28it/s]
# 다운로드 완료

# %%
# https://youtu.be/HJN28B7OSzw
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from tqdm import tqdm

keyword = "방탄소년단"

# 웹 접속 - 네이버 이미지 접속
print("접속중")
driver = webdriver.Chrome('c:/chromedriver.exe')
driver.implicitly_wait(30)

url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query={}'.format(keyword)
driver.get(url)

#페이지 스크롤 다운
body = driver.find_element_by_css_selector('body')
for i in range(10):
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)

#이미지 링크 수집
imgs = driver.find_elements_by_css_selector('img._img')
result = []
for img in tqdm(imgs):
    if 'http' in img.get_attribute('src'):
        result.append(img.get_attribute('src'))
# print(result)

driver.close()
print("수집완료")

#폴더생성
print("폴더생성")
import os
if not os.path.isdir('C:/Users/sdw19/0_naver_image_crawling/{}'.format(keyword)):
    os.mkdir('C:/Users/sdw19/0_naver_image_crawling/{}'.format(keyword))

#다운로드
print("다운로드")
from urllib.request import urlretrieve
for index , link in tqdm(enumerate(result)):
    start = link.rfind('.')
    end = link.rfind('&')
    # print(link[start:end])
    filetype = link[start:end] #.png

    urlretrieve(link , 'C:/Users/sdw19/0_naver_image_crawling/{}/{}{}{}'.format(keyword,keyword,index,filetype))

print("다운로드 완료")
# Out:
# 접속중
# 100%|████████████████████████████████████████████████████████████████████████████████| 250/250 [00:05<00:00, 49.63it/s]
# 2it [00:00, 11.76it/s]
# 수집완료
# 폴더생성
# 다운로드
# 250it [00:14, 16.77it/s]
# 다운로드 완료

# %%
# https://youtu.be/HJN28B7OSzw
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from tqdm import tqdm

keyword = "방탄소년단"

# 웹 접속 - 네이버 이미지 접속
print("접속중")
driver = webdriver.Chrome('c:/chromedriver.exe')
driver.implicitly_wait(30)

url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query={}'.format(keyword)
driver.get(url)

#페이지 스크롤 다운
body = driver.find_element_by_css_selector('body')
for i in range(10):
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)

#이미지 링크 수집
imgs = driver.find_elements_by_css_selector('img._img')
result = []
for img in tqdm(imgs):
    if 'http' in img.get_attribute('src'):
        result.append(img.get_attribute('src'))
# print(result)

driver.close()
print("수집완료")

#폴더생성
print("폴더생성")
import os
if not os.path.isdir('C:/Users/sdw19/0_naver_image_crawling/{}'.format(keyword)):
    os.mkdir('C:/Users/sdw19/0_naver_image_crawling/{}'.format(keyword))

#다운로드
print("다운로드")
from urllib.request import urlretrieve
for index , link in tqdm(enumerate(result)):
    start = link.rfind('.')
    end = link.rfind('&')
    # print(link[start:end])
    filetype = link[start:end] #.png

    urlretrieve(link , 'C:/Users/sdw19/0_naver_image_crawling/{}/{}{}{}'.format(keyword,keyword,index,filetype))

print("다운로드 완료")

#압축 - 메일
import zipfile
zip_file = zipfile.ZipFile('./{}.zip'.format(keyword),'w')

# print(os.listdir('./{}'.format(keyword)))
for image in os.listdir('./{}'.format(keyword)):
    print(image,"압축파일에 추가중")
    zip_file.write('C:/Users/sdw19/0_naver_image_crawling/{}/{}'.format(keyword,image), compress_type=zipfile.ZIP_DEFLATED)
zip_file.close()
print("압축완료")
# Out:
# 접속중
# 100%|████████████████████████████████████████████████████████████████████████████████| 250/250 [00:05<00:00, 47.62it/s]
# 2it [00:00, 13.06it/s]
# 수집완료
# 폴더생성
# 다운로드
# 250it [00:13, 18.01it/s]
# 다운로드 완료
# 방탄소년단0.jpg 압축파일에 추가중
# 방탄소년단1.jpg 압축파일에 추가중
# 방탄소년단10.jpg 압축파일에 추가중
# 방탄소년단100.jpg 압축파일에 추가중
# 방탄소년단101.jpg 압축파일에 추가중
# 방탄소년단102.jpg 압축파일에 추가중
# 방탄소년단103.jpg 압축파일에 추가중
# 방탄소년단104.jpg 압축파일에 추가중
# 방탄소년단105.jpg 압축파일에 추가중
# 방탄소년단106.jpg 압축파일에 추가중
# 방탄소년단107.jpg 압축파일에 추가중
# 방탄소년단108.jpg 압축파일에 추가중
# 방탄소년단109.jpg 압축파일에 추가중
# 방탄소년단11.jpg 압축파일에 추가중
# 방탄소년단110.jpg 압축파일에 추가중
# 방탄소년단111.jpg 압축파일에 추가중
# 방탄소년단112.jpg 압축파일에 추가중
# 방탄소년단113.jpg 압축파일에 추가중
# 방탄소년단114.jpg 압축파일에 추가중
# 방탄소년단115.jpg 압축파일에 추가중
# 방탄소년단116.jpg 압축파일에 추가중
# 방탄소년단117.jpg 압축파일에 추가중
# 방탄소년단118.jpg 압축파일에 추가중
# 방탄소년단119.jpg 압축파일에 추가중
# 방탄소년단12.jpg 압축파일에 추가중
# 방탄소년단120.jpg 압축파일에 추가중
# 방탄소년단121.jpg 압축파일에 추가중
# 방탄소년단122.jpg 압축파일에 추가중
# 방탄소년단123.jpg 압축파일에 추가중
# 방탄소년단124.jpg 압축파일에 추가중
# 방탄소년단125.jpg 압축파일에 추가중
# ...

# %%
# https://youtu.be/HJN28B7OSzw
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from tqdm import tqdm

def get_images(keyword):
    
    # 웹 접속 - 네이버 이미지 접속
    print("접속중")
    driver = webdriver.Chrome('c:/chromedriver.exe')
    driver.implicitly_wait(30)

    url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query={}'.format(keyword)
    driver.get(url)

    #페이지 스크롤 다운
    body = driver.find_element_by_css_selector('body')
    for i in range(10):
        body.send_keys(Keys.PAGE_DOWN)
        time.sleep(1)

    #이미지 링크 수집
    imgs = driver.find_elements_by_css_selector('img._img')
    result = []
    for img in tqdm(imgs):
        if 'http' in img.get_attribute('src'):
            result.append(img.get_attribute('src'))
    # print(result)

    driver.close()
    print("수집완료")

    #폴더생성
    print("폴더생성")
    import os
    if not os.path.isdir('C:/Users/sdw19/0_naver_image_crawling/{}'.format(keyword)):
        os.mkdir('C:/Users/sdw19/0_naver_image_crawling/{}'.format(keyword))

    #다운로드
    print("다운로드")
    from urllib.request import urlretrieve
    for index , link in tqdm(enumerate(result)):
        start = link.rfind('.')
        end = link.rfind('&')
        # print(link[start:end])
        filetype = link[start:end] #.png

        urlretrieve(link , 'C:/Users/sdw19/0_naver_image_crawling/{}/{}{}{}'.format(keyword,keyword,index,filetype))

    print("다운로드 완료")

    #압축 - 메일
    import zipfile
    zip_file = zipfile.ZipFile('./{}.zip'.format(keyword),'w')

    # print(os.listdir('./{}'.format(keyword)))
    for image in os.listdir('./{}'.format(keyword)):
        print(image,"압축파일에 추가중")
        zip_file.write('C:/Users/sdw19/0_naver_image_crawling/{}/{}'.format(keyword,image), compress_type=zipfile.ZIP_DEFLATED)
    zip_file.close()
    print("압축완료")

if __name__ == '__main__':
    keyword = input("수집할 이미지 키워드 입력 : ")
    get_images(keyword)
# Out:
# 수집할 이미지 키워드 입력 : 아이유
# 접속중
# 100%|████████████████████████████████████████████████████████████████████████████████| 350/350 [00:06<00:00, 53.61it/s]
# 2it [00:00, 12.46it/s]
# 수집완료
# 폴더생성
# 다운로드
# 300it [00:16, 17.71it/s]
# 다운로드 완료
# 아이유0.png 압축파일에 추가중
# 아이유1.png 압축파일에 추가중
# 아이유10.jpg 압축파일에 추가중
# 아이유100.jpg 압축파일에 추가중
# 아이유101.jpg 압축파일에 추가중
# 아이유102.jpg 압축파일에 추가중
# 아이유103.jpg 압축파일에 추가중
# 아이유104.jpg 압축파일에 추가중
# 아이유105.jpg 압축파일에 추가중
# 아이유106.jpg 압축파일에 추가중
# 아이유107.jpg 압축파일에 추가중
# 아이유108.jpg 압축파일에 추가중
# 아이유109.jpg 압축파일에 추가중
# 아이유11.jpg 압축파일에 추가중
# 아이유110.jpg 압축파일에 추가중
# 아이유111.jpg 압축파일에 추가중
# 아이유112.jpg 압축파일에 추가중
# 아이유113.jpg 압축파일에 추가중
# 아이유114.jpg 압축파일에 추가중
# 아이유115.jpg 압축파일에 추가중
# 아이유116.jpg 압축파일에 추가중
# 아이유117.jpg 압축파일에 추가중
# 아이유118.jpg 압축파일에 추가중
# 아이유119.jpg 압축파일에 추가중
# 아이유12.jpg 압축파일에 추가중
# 아이유120.jpg 압축파일에 추가중
# 아이유121.jpg 압축파일에 추가중
# 아이유122.jpg 압축파일에 추가중
# 아이유123.jpg 압축파일에 추가중
# 아이유124.jpg 압축파일에 추가중
# 아이유125.JPG 압축파일에 추가중
# 아이유126.jpg 압축파일에 추가중
# 아이유127.jpg 압축파일에 추가중
# ...
